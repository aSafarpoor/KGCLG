# %% [markdown]
# <a href="https://colab.research.google.com/github/aSafarpoor/KGCLG/blob/main/2_text2vec_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
from tqdm import tqdm 
import pandas as pd
import json
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %cd /content/drive/My Drive/
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive

# %%
# !mkdir KGCLG
# %cd KGCLG
# Out:
# /content/drive/My Drive/KGCLG

# %% [markdown]
# ## download data

# %%
# with open('meta.pickle', 'wb') as handle:
    # pickle.dump(meta, handle)

with open('ui.pickle', 'rb') as handle:
    ui = pickle.load(handle)

with open('meta.pickle', 'rb') as handle:
    meta = pickle.load(handle)

# with open('filename.pickle', 'rb') as handle:
    # b = pickle.load(handle)

# %% [markdown]
# ## create graph

# %%
meta.head(5)
# Out:
#          asin                      brand  \
# 0  0176496920  [TurningTechnologies,LLC]
# 1  0781776848   [AnatomicalChartCompany]
# 2  0781786606   [AnatomicalChartCompany]
# 3  0840026080    [ResponsiveInnovations]
# 4  1587790319   [AnatomicalChartCompany]
#
#                                             imageURL  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1
# 2
# 3  https://images-na.ssl-images-amazon.com/images...
# 4
#
#                                      imageURLHighRes  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1
# 2
# 3  https://images-na.ssl-images-amazon.com/images...
# 4
#
#                                             category  \
# 0  [Industrial & Scientific, Industrial Electrica...
# 1       [Industrial & Scientific, Science Education]
# 2  [Industrial & Scientific, Science Education, C...
# 3  [Industrial & Scientific, Industrial Electrica...
# 4  [Industrial & Scientific, Science Education, C...
#
# ...

# %% [markdown]
# ## SentenceBert
#
# based on: https://www.analyticsvidhya.com/blog/2020/08/top-4-sentence-embedding-techniques-using-python/

# %%
try:
    from sentence_transformers import SentenceTransformer
except:
    ! pip install sentence_transformers
    from sentence_transformers import SentenceTransformer

sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')
def embedding_sentenceBert(sent):
    sent_embedding = sbert_model .encode(sent)
    return sent_embedding
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 5.5 MB 33.5 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 58.6 MB/s
# ...
#      |████████████████████████████████| 163 kB 34.7 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 46.0 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=88941e4ead48e08bce3fcafcf5a456eb8e6346ef364631ca9e0fb39662acfc63
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# ...
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# ...

# %%
tqdm.pandas()
meta['text2vec'] = meta['text'].progress_apply(embedding_sentenceBert)

# %%
import pickle
with open('embedded_meta.p', 'wb') as fp:
    pickle.dump(meta, fp, protocol=pickle.HIGHEST_PROTOCOL)
